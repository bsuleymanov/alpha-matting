# %%
from backbones import SUPPORTED_BACKBONES

backbone = SUPPORTED_BACKBONES['resnet18'](3)
# Out:
# [ResNet] Initialize weights...

# %%
backbone
# Out:
# ResNet18Backbone(
#   (model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
from torch import nn

class BigModel(nn.Module):
    def __init__(self):
        super(BigModel, self).__init__()
        self.backbone = SUPPORTED_BACKBONES['resnet18'](3)
        trained_dict = torch.load("pretrained/resnet18_human_seg.ckpt", map_location="cpu")
        self.backbone.load_state_dict(trained_dict, strict=False)

# %%
import torch
model = BigModel()
# Out:
# [ResNet] Initialize weights...

# %%
model.backbone(torch.ones([1, 3, 256, 256]))
# Out:
# [tensor([[[[4.7645, 0.4171, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [8.1147, 2.6773, 0.6123,  ..., 0.6123, 0.6123, 0.0000],
#            [7.3543, 1.7633, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            ...,
#            [7.3543, 1.7633, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [7.3543, 1.7633, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [8.7316, 6.0489, 7.0746,  ..., 7.0746, 7.0746, 4.4368]],
#
#           [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 1.7861, 0.1584,  ..., 0.1584, 0.1584, 0.0000],
#            ...,
#            [0.0000, 1.7861, 0.1584,  ..., 0.1584, 0.1584, 0.0000],
#            [0.0000, 1.7861, 0.1584,  ..., 0.1584, 0.1584, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#           [[0.0000, 1.6187, 3.6587,  ..., 3.6587, 3.6587, 0.1661],
# ...
